# %%
import pandas as pd

# %%
amazonData = pd.read_csv("amazon_prime_titles.csv")
amazonData = amazonData[["title","listed_in","cast","description"]]
amazonData.columns = ["title", "genre", "cast", "plot"]
amazonData
# Out:
#                         title                    genre  \
# 0         The Grand Seduction            Comedy, Drama
# 1        Take Care Good Night     Drama, International
# 2        Secrets of Deception  Action, Drama, Suspense
# 3          Pink: Staying True              Documentary
# 4               Monster Maker           Drama, Fantasy
# ...                       ...                      ...
# 9663      Pride Of The Bowery                   Comedy
# 9664            Planet Patrol                 TV Shows
# 9665                  Outpost                   Action
# 9666  Maradona: Blessed Dream            Drama, Sports
# 9667              Harry Brown  Action, Drama, Suspense
#
#                                                    cast  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar
# 2     Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...
# 3     Interviews with: Pink, Adele, Beyoncé, Britney...
# ...

# %%
netflixData = pd.read_csv("netflix_titles.csv")
netflixData = netflixData[["title","listed_in","cast","description"]]
netflixData.columns = ["title", "genre", "cast", "plot"]
netflixData.iloc[8616]
# Out:
# title                                        Transcendence
# genre                          Sci-Fi & Fantasy, Thrillers
# cast     Johnny Depp, Rebecca Hall, Morgan Freeman, Pau...
# plot     Two computer scientists work to achieve techno...
# Name: 8616, dtype: object

# %%
huluData = pd.read_csv("hulu_titles.csv")
huluData = huluData[["title","listed_in","description"]]
huluData.columns = ["title", "genre", "plot"]
huluData
# Out:
#                                title                                   genre  \
# 0     Ricky Velez: Here's Everything                        Comedy, Stand Up
# 1                       Silent Night                  Crime, Drama, Thriller
# 2                       The Marksman                        Action, Thriller
# 3                               Gaia                                  Horror
# 4                           Settlers               Science Fiction, Thriller
# ...                              ...                                     ...
# 3068  Star Trek: The Original Series             Action, Adventure, Classics
# 3069              Star Trek: Voyager      Action, Adventure, Science Fiction
# 3070                       The Fades  Horror, International, Science Fiction
# 3071               The Twilight Zone     Classics, Science Fiction, Thriller
# 3072             Tokyo Magnitude 8.0             Anime, Drama, International
#
# ...

# %%
disneyData = pd.read_csv("disney_plus_titles.csv")
disneyData = disneyData[["title","listed_in","cast","description"]]
disneyData.columns = ["title", "genre", "cast", "plot"]
disneyData
# Out:
#                                                  title  \
# 0     Duck the Halls: A Mickey Mouse Christmas Special
# 1                               Ernest Saves Christmas
# 2                         Ice Age: A Mammoth Christmas
# 3                           The Queen Family Singalong
# 4                                The Beatles: Get Back
# ...                                                ...
# 1445                          X-Men Origins: Wolverine
# 1446    Night at the Museum: Battle of the Smithsonian
# 1447                                   Eddie the Eagle
# 1448                              Bend It Like Beckham
# 1449             Captain Sparky vs. The Flying Saucers
#
#                                               genre  \
# 0                                 Animation, Family
# 1                                            Comedy
# 2                         Animation, Comedy, Family
# 3                                           Musical
# ...

# %%
allData = pd.concat([amazonData, netflixData, huluData, disneyData], ignore_index=True)
allData
# Out:
#                                                 title  \
# 0                                 The Grand Seduction
# 1                                Take Care Good Night
# 2                                Secrets of Deception
# 3                                  Pink: Staying True
# 4                                       Monster Maker
# ...                                               ...
# 22993                        X-Men Origins: Wolverine
# 22994  Night at the Museum: Battle of the Smithsonian
# 22995                                 Eddie the Eagle
# 22996                            Bend It Like Beckham
# 22997           Captain Sparky vs. The Flying Saucers
#
#                                                genre  \
# 0                                      Comedy, Drama
# 1                               Drama, International
# 2                            Action, Drama, Suspense
# 3                                        Documentary
# ...

# %%
allData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22998 entries, 0 to 22997
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   22998 non-null  object
#  1   genre   22998 non-null  object
#  2   cast    17677 non-null  object
#  3   plot    22994 non-null  object
# dtypes: object(4)
# memory usage: 718.8+ KB

# %%
def movie_text(m):
    return f"{m['title']} | {', '.join(m['genre'])} | Cast: {', '.join(m['cast'][:5])} | {m['plot']}"

# %%
corpus = [movie_text(m) for i,m in netflixData.iterrows()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-368a533259f8> in <module>
# ----> 1 corpus = [movie_text(m) for i,m in netflixData.iterrows()]
#
# <ipython-input-35-368a533259f8> in <listcomp>(.0)
# ----> 1 corpus = [movie_text(m) for i,m in netflixData.iterrows()]
#
# <ipython-input-34-7c4d3933a458> in movie_text(m)
#       1 def movie_text(m):
# ----> 2     return f"{m['title']} | {', '.join(m['genre'])} | Cast: {', '.join(m['cast'][:5])} | {m['plot']}"
#
# TypeError: 'float' object is not subscriptable

# %%
for i,m in netflixData.iterrows():
    if type(m['cast']) == float:
        print(m['cast'])
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ...

# %%
netflixData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   8807 non-null   object
#  1   genre   8807 non-null   object
#  2   cast    7982 non-null   object
#  3   plot    8807 non-null   object
# dtypes: object(4)
# memory usage: 275.3+ KB

# %%
netflixData['cast'].fillna('Unknown')
# Out:
# 0                                                 Unknown
# 1       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                 Unknown
# 4       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
#                               ...
# 8802    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                              Unknown
# 8804    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# Name: cast, Length: 8807, dtype: object
